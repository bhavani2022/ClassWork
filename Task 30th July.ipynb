# %% [markdown]
# Task ::::1. find out average rating on weekly basis keep in mind thth they take 2 days leave per week
#          2. total working days for each agent
#         3.total query tht they hav taken
#         4.total feedback tht they have recieved
#         5.a agent name who have average rating between 3.5 to 4
#         6.agent names who have less than 3.5 rating
#         7.agent name who have more than 4,.5 rating
#         8.how many feedbacks agent have recieved more than 4.5 VERAGE
#         9.average weekly response for each agent
#         10.average weekly resolution time for each agent
#         11.list of all agent names
#         12.% of chat on which they have recieved the feedback
# 13 . Total contributation hour for each and every agents weekly basis
# 14. total percentage of active hour for a month
#
# sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\gpalb\OneDrive\Desktop\FSDS\data fsds\Agent_Login_Report.xls',skiprows=2)

# %%
df1=pd.read_excel(r'C:\Users\gpalb\OneDrive\Desktop\FSDS\data fsds\AgentPerformance.xlsx',skiprows=1)

# %%
df
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
#1. find out average rating on weekly basis keep in mind thth they take 2 days leave per week

df1['date']=pd.to_datetime(df1['Date'])

# %%
df1.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
# 2                00:11:36            4.55              11 2022-07-30
# 3                00:15:46            4.71               7 2022-07-30
# 4                00:16:33            3.67               6 2022-07-30
#
#    date_week
# 0         30
# 1         30
# 2         30
# 3         30
# 4         30

# %%
df1['date_week']=df1['date'].dt.isocalendar().week

# %%
df1['date_days']=df1['date'].dt.day

# %%
df1.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
#
#    date_week  date_days
# 0         30         30
# 1         30         30

# %%
df1_mean=df1.groupby(['Agent Name','date_week'])['Average Rating'].mean().to_frame()

# %%
df1_mean
# Out:
#                       Average Rating
# Agent Name date_week
# Abhishek   26               0.000000
#            27               0.000000
#            28               0.000000
#            29               0.000000
#            30               0.000000
# ...                              ...
# Zeeshan    26               0.000000
#            27               1.307143
#            28               2.948571
#            29               3.180000
#            30               2.760000
#
# [350 rows x 1 columns]

# %%
# 2. total working days for each agent

# %%
df1.groupby('Agent Name')['date_days'].count()
# Out:
# Agent Name
# Abhishek         30
# Aditya           30
# Aditya Shinde    30
# Aditya_iot       30
# Amersh           30
#                  ..
# Uday Mishra      30
# Vasanth P        30
# Vivek            30
# Wasim            30
# Zeeshan          30
# Name: date_days, Length: 70, dtype: int64

# %%
#  3.total query tht they hav taken

# %%
df.head(2)
# Out:
#    SL No               Agent       Date   Login Time  Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 1      2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17

# %%
df1.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
#
#    date_week  date_days
# 0         30         30
# 1         30         30

# %%
df1.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %%
#4.total feedback tht they have recieved

# %%
df1.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %%
#5. agent name who have average rating between 3.5 to 4

# %%
df1[(df1['Average Rating']>3.5) & (df1['Average Rating'] <=4)]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 73      Boktiar Ahmed Bappy
# 76            Prateek _iot
# 78            Nandani Gupta
#                ...
# 1941         Jawala Prakash
# 2018          Sanjeev Kumar
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# 2097          Sanjeev Kumar
# Name: Agent Name, Length: 111, dtype: object

# %%
# 6.agent names who have less than 3.5 rating

# %%
df1[(df1['Average Rating']< 3.5)]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %%
#  7.agent name who have more than 4.5 rating

# %%
df1[(df1['Average Rating'] > 4.5)]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %%
#8.how many feedbacks agent have recieved more than 4.5 aVERAGE

# %%
df1.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
#
#    date_week  date_days
# 0         30         30
# 1         30         30

# %%
df1.groupby('Agent Name')['Total Feedback'].mean() > 4.5
# Out:
# Agent Name
# Abhishek         False
# Aditya           False
# Aditya Shinde     True
# Aditya_iot       False
# Amersh           False
#                  ...
# Uday Mishra      False
# Vasanth P        False
# Vivek            False
# Wasim             True
# Zeeshan           True
# Name: Total Feedback, Length: 70, dtype: bool

# %%
# 9.average weekly response for each agent

# %%
df1.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
#
#    date_week  date_days
# 0         30         30
# 1         30         30

# %%
def get_seconds(time_str):
    #print('Time in hh:mm:ss:', time_str)
    # split in hh, mm, ss
    hh, mm, ss = time_str.split(':')
    return int(hh) * 3600 + int(mm) * 60 + int(ss)

# %%
avg_response_sec=[]
for t in df1['Average Response Time']:
    avg_response_sec.append(get_seconds(t))
avg_response_sec
df1['avg_response_sec'] = avg_response_sec

# %%
df1.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
# 2                00:11:36            4.55              11 2022-07-30
# 3                00:15:46            4.71               7 2022-07-30
# 4                00:16:33            3.67               6 2022-07-30
#
#    date_week  date_days  avg_response_sec
# 0         30         30                38
# ...

# %%
df1.groupby(['Agent Name','date_week'])['avg_response_sec'].mean()
# Out:
# Agent Name  date_week
# Abhishek    26             0.000000
#             27             0.000000
#             28             0.000000
#             29             0.000000
#             30             0.000000
#                             ...
# Zeeshan     26             0.000000
#             27            23.571429
#             28           123.428571
#             29            62.857143
#             30            63.833333
# Name: avg_response_sec, Length: 350, dtype: float64

# %%
#10.average weekly resolution time for each agent

# %%
df1.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
#
#    date_week  date_days  avg_response_sec
# 0         30         30                38
# 1         30         30                75

# %%
avg_resolution_time_sec=[]
for t in df1['Average Resolution Time']:
    avg_resolution_time_sec.append(get_seconds(t))
avg_resolution_time_sec
df1['avg_resolution_time_sec'] = avg_resolution_time_sec
df1.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
# 2                00:11:36            4.55              11 2022-07-30
# 3                00:15:46            4.71               7 2022-07-30
# 4                00:16:33            3.67               6 2022-07-30
#
#    date_week  date_days  avg_response_sec  avg_resolution_time_sec
# ...

# %%
 #11.list of all agent names

# %%
set(df['Agent'])
# Out:
# {'Aditya Shinde',
#  'Aditya_iot ',
#  'Amersh ',
#  'Ameya Jain',
#  'Ankitjha ',
#  'Anurag Tiwari',
#  'Aravind ',
#  'Ayushi Mishra',
#  'Bharath ',
#  'Boktiar Ahmed Bappy',
#  'Chaitra K Hiremath',
#  'Deepranjan Gupta',
#  'Dibyanshu ',
#  'Harikrishnan Shaji',
#  'Hrisikesh Neogi',
#  'Hyder Abbas',
#  'Ineuron Intelligence ',
#  'Ishawant Kumar',
#  'Jawala Prakash',
#  'Jaydeep Dixit',
#  'Khushboo Priya',
#  'Madhulika G',
#  'Mahesh Sarade',
#  'Maitry ',
#  'Manjunatha A',
#  'Mithun S',
#  'Mukesh ',
#  'Muskan Garg',
#  'Nandani Gupta',
#  'Nishtha Jain',
#  'Nitin M',
#  'Prabir Kumar Satapathy',
#  'Prateek _iot ',
#  'Prerna Singh',
#  'Rishav Dash',
#  'Saikumarreddy N',
#  'Sanjeev Kumar',
#  'Saurabh Shukla',
#  'Shiva Srivastava',
#  'Shivan K',
#  'Shivananda Sonwane',
#  'Shubham Sharma',
#  'Sowmiya Sivakumar',
#  'Sudhanshu Kumar',
#  'Suraj S Bilgi',
#  'Swati ',
#  'Tarun ',
#  'Wasim ',
#  'Zeeshan '}

# %%
 #  12.% of chat on which they have recieved the feedback

# %%
df1.groupby(['Agent Name','Total Chats'])['Total Feedback'].sum()
# Out:
# Agent Name     Total Chats
# Abhishek       0               0
# Aditya         0               0
# Aditya Shinde  0               0
#                8               7
#                14              9
#                               ..
# Zeeshan        36             28
#                37             25
#                41             25
#                46             28
#                92             35
# Name: Total Feedback, Length: 638, dtype: int64

# %%
#13 . Total contributation hour for each and every agents weekly basis

# %%
df.head(2)
# Out:
#    SL No               Agent       Date   Login Time  Logout Time  Duration  \
# 0      1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM  02:04:10
# 1      2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM  00:00:17
#
#    week
# 0    30
# 1    30

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['week'] = df['Date'].dt.isocalendar().week

# %%
Total_duration_secs=[]
for t in df['Duration']:
    Total_duration_secs.append(get_seconds(t))
Total_duration_secs
df['Total_duration_secs'] = Total_duration_secs

# %%
df['hours']=df['Total_duration_secs']//3600

# %%
df.groupby(['Agent','week'])['hours'].mean()
# Out:
# Agent          week
# Aditya Shinde  30        0.000000
# Aditya_iot     29        1.666667
#                30        1.166667
# Amersh         30        0.500000
# Ameya Jain     29        3.000000
#                           ...
# Tarun          26      514.000000
# Wasim          29        2.000000
#                30        2.272727
# Zeeshan        29        3.833333
#                30        6.000000
# Name: hours, Length: 89, dtype: float64

# %%
#14. total percentage of active hour for a month

# %%
df['month'] = df['Date'].dt.month
df
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM
# 996    997            Bharath  2022-07-20  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun  2022-07-01  01:52:47 AM  12:01:07 PM
#
#       Duration  week  Total_duration_secs  hours  month
# 0     02:04:10    30                 7450      2      7
# ...

# %%
100*df['hours']/df.groupby('month')['hours'].transform('sum')
# Out:
# 0       0.105097
# 1       0.000000
# 2       0.105097
# 3       0.000000
# 4       0.052549
#          ...
# 995     0.262743
# 996     0.315292
# 997     0.262743
# 998     0.262743
# 999    27.009984
# Name: hours, Length: 1000, dtype: float64
